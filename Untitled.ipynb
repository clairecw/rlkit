# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/slowerlearning/slowerlearning_2020_11_04_12_27_52_0000--s-0/progress.csv")

# %%
plt.figure(figsize=(16, 5))
df['evaluation/Returns Mean'].plot()
plt.ylabel("Returns Mean")
plt.xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %%
pd.set_option('display.max_columns', None)
df.describe()
# Out:
#              Epoch  evaluation/Actions Max  evaluation/Actions Mean  \
# count  1000.000000             1000.000000              1000.000000
# mean    499.500000                0.998971                -0.055277
# std     288.819436                0.031592                 0.065334
# min       0.000000                0.001398                -0.539199
# 25%     249.750000                1.000000                -0.082591
# 50%     499.500000                1.000000                -0.044420
# 75%     749.250000                1.000000                -0.016508
# max     999.000000                1.000000                 0.330417
#
#        evaluation/Actions Min  evaluation/Actions Std  \
# count             1000.000000             1000.000000
# mean                -0.998998                0.917397
# std                  0.031394                0.036201
# min                 -1.000000                0.000094
# 25%                 -1.000000                0.910074
# ...

# %%
plt.figure(figsize=(16, 5))
df['evaluation/Returns Std'].plot()
plt.ylabel("Returns Std")
plt.xlabel("Epoch")
plt.show()

# %%
plt.figure(figsize=(16, 5))
df['evaluation/Rewards Mean'].plot()
